# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import re

#load the data
X = []
Y = []
for line in open('linear_regression_class/data_1d.csv') : 
    x,y = line.split(',')
    X.append(float(x))
    Y.append(float(y))

#turn X and Y into numpy arrays
X = np.array(X)
Y = np.array(Y)

#plot the data
plt.scatter(X,Y)
plt.show()

# %%
# apply the equations we learned to calculate a and b

denominator = X.dot(X) - X.mean() * X.sum()
a = (X.dot(Y) - Y.mean() * X.sum()) / denominator
b = (Y.mean() * X.dot(X) - X.mean() * X.dot(Y)) / denominator

# calculated predicted Y
Yhat = a*X + b
plt.scatter(X,Y)
plt.plot(X, Yhat,'k')
plt.show()

# %%
# calculate r-squared
d1 = Y - Yhat
d2 = Y - Y.mean()
r2 = 1 - d1.dot(d1) / d2.dot(d2)
print('The R-squared is:',r2)
# Out:
# The R-squared is: 0.991183820298

# %%
X = []
Y = []

non_decimal = re.compile(r'[^\d]+')

for line in open('linear_regression_class/moore.csv') : 
    r = line.split('\t')
    print(r[2],', ',r[1])
    x = int(non_decimal.sub('', r[2].split('[')[0]))
    y = int(non_decimal.sub('', r[1].split('[')[0]))
    X.append(x)
    Y.append(y)
    
X = np.array(X)
Y = np.array(Y)

plt.scatter(X,Y)
plt.show()
# Out:
# 1971 ,  2,300
# 1972 ,  3,500
# 1974 ,  4,500
# 1974 ,  4,100
# 1974 ,  5,000
# 1974[7] ,  8,000
# 1975 ,  3,510[8]
# 1976 ,  6,500
# 1976 ,  8,500
# 1978 ,  29,000
# 1978 ,  9,000
# 1979 ,  29,000
# 1979 ,  68,000
# 1981 ,  11,500[9]
# 1982 ,  55,000
# 1982 ,  134,000
# 1983 ,  22,000[10]
# 1984 ,  190,000[11]
# 1985 ,  25,000[11]
# 1985 ,  275,000
# 1985[13] ,  16,000[12]
# 1986 ,  30,000[11]
# 1987 ,  553,000[15]
# 1988 ,  180,000[16]
# 1988 ,  250,000[17]
# 1989 ,  300,000
# 1989 ,  1,180,235
# 1991 ,  35,000
# 1991 ,  1,350,000
# 1993 ,  3,100,000
# 1994 ,  578,977[18]
# 1995 ,  5,500,000[19]
# 1995 ,  2,500,000[11]
# 1996 ,  4,300,000
# 1997 ,  8,800,000
# 1997 ,  7,500,000
# 1998 ,  7,500,000
# 1999 ,  21,300,000
# 1999 ,  22,000,000
# 1999 ,  111,000[11]
# 1999 ,  27,400,000
# 1999 ,  9,500,000
# 2000 ,  42,000,000
# 2000 ,  21,000,000
# 2001 ,  45,000,000
# 2002 ,  220,000,000
# 2002 ,  55,000,000
# 2003 ,  105,900,000
# 2003 ,  54,300,000
# 2003 ,  410,000,000
# 2004 ,  592,000,000
# 2004 ,  112,000,000
# 2005 ,  169,000,000
# 2005 ,  228,000,000
# 2006 ,  241,000,000
# 2006 ,  291,000,000
# 2006 ,  1,700,000,000[26]
# 2006 ,  184,000,000
# 2006 ,  362,000,000
# 2007 ,  463,000,000[20]
# 2007 ,  26,000,000[21]
# 2007 ,  169,000,000
# 2007 ,  411,000,000
# 2007 ,  789,000,000
# 2008 ,  758,000,000[20]
# 2008 ,  47,000,000
# 2008 ,  230,000,000
# 2008 ,  731,000,000
# 2008 ,  1,900,000,000
# 2009 ,  904,000,000
# 2010 ,  1,000,000,000[22]
# 2010 ,  1,200,000,000
# 2010 ,  2,300,000,000[30]
# 2010 ,  2,000,000,000[28]
# 2010 ,  1,400,000,000
# 2010 ,  1,170,000,000
# 2011 ,  2,600,000,000
# 2011 ,  1,160,000,000
# 2011 ,  2,270,000,000[29]
# 2012 ,  5,000,000,000[34]
# 2012 ,  1,200,000,000[23]
# 2012 ,  3,100,000,000
# 2012 ,  2,100,000,000
# 2012 ,  1,303,000,000
# 2012 ,  1,400,000,000
# 2012 ,  2,750,000,000
# 2013 ,  4,200,000,000
# 2013 ,  1,000,000,000
# 2013 ,  1,860,000,000
# 2013 ,  5,000,000,000
# 2014 ,  4,310,000,000[33]
# 2014 ,  5,560,000,000[35]
# 2014 ,  2,600,000,000[31]
# 2014 ,  2,000,000,000
# 2014 ,  3,000,000,000[32]
# 2014 ,  1,400,000,000[25]
# 2015 ,  1,900,000,000[27]
# 2015 ,  3,990,000,000
# 2015 ,  7,100,000,000
# 2015 ,  cca 1,750,000,000
# 2015 ,  10,000,000,000[37]
# 2016 ,  ~7,200,000,000[36]

# %%
Y = np.log(Y)
plt.scatter(X,Y)
plt.show()

# %%
denominator = X.dot(X) - X.mean() * X.sum()
a = (X.dot(Y) - Y.mean() * X.sum()) / denominator
b = (Y.mean() * X.dot(X) - X.mean() * X.dot(Y)) / denominator
Yhat = a*X + b

plt.scatter(X,Y)
plt.plot(X, Yhat,'k')
plt.show()

# %%
d1 = Y - Yhat
d2 = Y - Y.mean()
r2 = 1 - d1.dot(d1) / d2.dot(d2)
print('a:', a, 'b:',b)
print('the r-squared is:', r2)
# Out:
# a: 0.351043573365 b: -685.000284382
# the r-squared is: 0.952944285229

# %%
# log(tc) = a*year + b  //tc = transistor count
# tc = exp(a*year) * exp(b)
# 2*tc = 2 * exp(a*year) * exp(b) = exp(ln(2)) * exp(a*year) * exp(b)
#      = exp(b) * exp(a*year + ln(2))
# exp(b) * exp(a*year2) = exp(b) * exp(a*year1 + ln(2))
# a*year2 = a*year1 + ln(2)
# year2 = year1 + ln(2)/a
print('time to double:',np.log(2)/a)
# Out:
# time to double: 1.97453317238
