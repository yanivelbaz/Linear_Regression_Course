# %%
import numpy as np

# J = (w1)^2 + (w2)^4

w1 = 20
w2 = 20

W = [w1**2, w2**4]
print('w:',W)

W = np.array(W)
W_tag = [2*w1, 4*w2**3]
step = np.array([0.01,0.01])
W_tag = np.array(W_tag)
#W = W.dot(np.eye(2)).T
for i in range(400) :     
    W = W - step*W_tag
    W_tag = [2*(W[0]**0.5), 4*(W[1]**0.25)**3]
    print(W)
# Out:
# w: [400, 160000]
# [    399.6  159680. ]
# [    399.20020005  159360.4801201 ]
# [    398.80060015  159041.43988   ]
# [    398.4012003   158722.87879964]
# [    398.0020005  158404.7963992]
# [    397.60300075  158087.1921991 ]
# [    397.20420105  157770.06572   ]
# [    396.8056014  157453.4164828]
# [    396.4072018   157137.24400864]
# [    396.00900225  156821.54781891]
# [    395.61100276  156506.32743522]
# [    395.21320331  156191.58237943]
# [    394.81560391  155877.31217366]
# [    394.41820456  155563.51634023]
# [    394.02100526  155250.19440173]
# [    393.62400602  154937.34588098]
# [    393.22720682  154624.97030105]
# [    392.83060767  154313.06718524]
# [    392.43420858  154001.63605708]
# [    392.03800953  153690.67644037]
# [    391.64201054  153380.18785912]
# [    391.24621159  153070.16983761]
# [    390.8506127   152760.62190032]
# [    390.45521386  152451.54357201]
# [    390.06001507  152142.93437766]
# [    389.66501632  151834.79384249]
# ...
